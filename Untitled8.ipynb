# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Year 2009-2010.csv.csv")
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 211222  509851     21529              RED RETROSPOT TOASTRACK         6
# 211223  509851     21110          LARGE CAKE TOWEL PINK SPOTS         6
# 211224  509851     21112        SWISS ROLL TOWEL, PINK  SPOTS         6
# 211225  509851     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR         9
# 211226  509851     21911                   GARDEN METAL SIGN         12
#
#            InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#       InvoiceDate  Price  Customer ID         Country
# 0  12/1/2009 7:45   6.95      13085.0  United Kingdom
# 1  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 2  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 3  12/1/2009 7:45   2.10      13085.0  United Kingdom
# 4  12/1/2009 7:45   1.25      13085.0  United Kingdom

# %%
df.isnull().sum()
# Out:
# Invoice            0
# StockCode          0
# Description     1783
# Quantity           0
# InvoiceDate        0
# Price              0
# Customer ID    47292
# Country            1
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 211222    False
# 211223    False
# 211224    False
# 211225    False
# 211226    False
# Length: 211227, dtype: bool

# %%
print((df.isnull().mean()*100).round(2))  #usefull for seeing how bad missing data problem is.
# Out:
# Invoice         0.00
# StockCode       0.00
# Description     0.84
# Quantity        0.00
# InvoiceDate     0.00
# Price           0.00
# Customer ID    22.39
# Country         0.00
# dtype: float64

# %%
missing_summary = pd.DataFrame({
    "missing_count": df.isnull().sum(),
    "missing_pct": (df.isnull().mean() * 100).round(2),
    "dtype": df.dtypes
}).sort_values(by="missing_count", ascending=False)

print(missing_summary)   #this gives neat table with count, percentage,and column type
# Out:
#              missing_count  missing_pct    dtype
# Customer ID          47292        22.39  float64
# Description           1783         0.84   object
# Country                  1         0.00   object
# Invoice                  0         0.00   object
# StockCode                0         0.00   object
# Quantity                 0         0.00    int64
# InvoiceDate              0         0.00   object
# Price                    0         0.00  float64

# %%
# Show the first 10 rows with any missing values
df[df.isnull().any(axis=1)].head(10)
# Out:
#      Invoice StockCode                   Description  Quantity  \
# 263   489464     21733                  85123a mixed       -96
# 283   489463     71477                         short      -240
# 284   489467    85123A                   21733 mixed      -192
# 470   489521     21646                           NaN       -50
# 577   489525    85226C     BLUE PULL BACK RACING CAR         1
# 578   489525     85227   SET/6 3D KIT CARDS FOR KIDS         1
# 1055  489548     22271          FELTCRAFT DOLL ROSIE         1
# 1056  489548     22254          FELT TOADSTOOL LARGE        12
# 1057  489548     22273          FELTCRAFT DOLL MOLLY         3
# 1058  489548     22195  LARGE HEART MEASURING SPOONS         1
#
#           InvoiceDate  Price  Customer ID         Country
# 263   12/1/2009 10:52   0.00          NaN  United Kingdom
# 283   12/1/2009 10:52   0.00          NaN  United Kingdom
# 284   12/1/2009 10:53   0.00          NaN  United Kingdom
# ...

# %%
# 1. Distribution of Quantity
plt.figure(figsize=(8,5))
sns.histplot(df["Quantity"], bins=50, kde=True)
plt.title("Distribution of Quantity")
plt.show()

# %%
# 2. Top 10 Countries by Number of Transactions
plt.figure(figsize=(10,6))
df["Country"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Countries by Transactions")
plt.ylabel("Number of Transactions")
plt.show()
